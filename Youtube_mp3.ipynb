# %%
# !pip install moviepy

# %%
from pytube import YouTube

# %%
SAVE_PATH = "/content/drive/MyDrive/Youtube/Video" #to_do 
 
link="https://youtu.be/KDCIycGqacU"
yt = YouTube(link) 
yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution')[1].download(SAVE_PATH)
# Out:
# '/content/drive/MyDrive/Youtube/Video/Data Science vs Software development - Which career path is the most Rewarding.mp4'

# %%
import moviepy.editor as mp 


clip=mp.VideoFileClip(r"/content/drive/MyDrive/Youtube/Video/Data Science vs Software development - Which career path is the most Rewarding.mp4")

 
# Insert Local Audio File Path 

clip.audio.write_audiofile(r"/content/drive/MyDrive/Youtube/Audio/convert2.mp3")
# Out:
# [MoviePy] Writing audio in /content/drive/MyDrive/Youtube/Audio/convert2.mp3
# 100%|██████████| 12036/12036 [00:15<00:00, 783.21it/s]
# [MoviePy] Done.
